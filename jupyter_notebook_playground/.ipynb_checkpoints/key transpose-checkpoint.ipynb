# %%
#required library
from music21 import *
import music21
import os
import glob
import re
import numpy as np
import json

# %%
#key transpose profile
MtoC={
    'Gb':-6,
    'F':-5,
    'E':-4,
    'D#':-3,
    'Eb':-3,
    'D':-2,
    'C#':-1,
    'Db':-1,
    'C':0,    
    'B':1,
    'A#':2,
    'Bb':2,
    'A':3,
    'G#':4,
    'Ab':4,
    'G':5,
    'F#':6
}
mtoA={
    'D#':6,
    'G#':5,
    'Ab':5,
    'C#':4,
    'F#':3,
    'B':2,
    'E':1,
    'A':0,
    'D':-1,
    'G':-2,
    'C':-3,
    'F':-4,
    'Bb':-5,
    'Eb':-6
}

# %%
#read file
c = converter.parse('./Chopin_F._Nocturne_in_E_Major,_Op.26_No.2.mxl')

# %%
#remove key signature
for e in c.recurse().getElementsByClass(key.KeySignature):
    while e.sharps!=0:
        e.transpose(-1,inPlace=True)

# %%
#remove key signature
for e in c.recurse().getElementsByClass(stream):
    print(e)

# %%
def cal_offset(e):
    if e is None:
        return 0
    return e.offset+cal_offset(e.activeSite)

# %%
#extract notes
all_notes=[]
for el in c.recurse().notes:
    if el.lyric is not None:
        el.lyric=el.lyric.replace('♭','b')
    
    #print(el)
    #print([el.getOffsetBySite(c),el.lyric, el, el.activeSite,el.offset, el.activeSite.offset])
    all_notes.append([el.lyric, el, cal_offset(el)])
    
    #DEBUG
    #print([el.lyric, el, cal_offset(el)])

# %%
#sort by first occurence
b = sorted(all_notes, key=lambda x: x[0] if x[0] is not None else "ZZZ")
b=sorted(all_notes,key=lambda x: x[-1])


#DEBUG
for e in b:
    print(e)
# Out:
# [None, <music21.note.Note B>, 0.0]
# ['EM(I)', <music21.note.Note G#>, 1.0]
# [None, <music21.note.Note E>, 1.0]
# [None, <music21.chord.Chord E3 G#3 C#4>, 2.0]
# [None, <music21.note.Note A>, 2.5]
# [None, <music21.note.Note B>, 3.0]
# [None, <music21.chord.Chord B2 G#3 B3>, 3.0]
# [None, <music21.note.Note D#>, 3.5]
# [None, <music21.note.Note E>, 4.0]
# [None, <music21.chord.Chord B3 E4 G#4>, 4.0]
# [None, <music21.note.Note C#>, 4.5]
# ['V', <music21.note.Note B>, 5.0]
# [None, <music21.note.Note B>, 5.0]
# [None, <music21.chord.Chord F#3 D#4>, 6.0]
# [None, <music21.note.Note F#>, 7.0]
# [None, <music21.chord.Chord A3 D#4>, 7.0]
# [None, <music21.chord.Chord B2 A3>, 8.0]
# [None, <music21.note.Note G#>, 8.5]
# ['VI', <music21.note.Note E>, 9.0]
# [None, <music21.chord.Chord C#2 C#3>, 9.0]
# [None, <music21.chord.Chord E3 G#3 C#4>, 10.0]
# ['AM(V)', <music21.note.Note F#>, 11.0]
# [None, <music21.chord.Chord B1 B2>, 11.0]
# [None, <music21.note.Note G#>, 11.5]
# [None, <music21.note.Note A>, 12.0]
# [None, <music21.chord.Chord E3 G#3 D4>, 12.0]
# [None, <music21.note.Note B>, 12.5]
# ['I', <music21.note.Note C#>, 13.0]
# [None, <music21.chord.Chord A1 A2>, 13.0]
# [None, <music21.chord.Chord E3 C#4>, 14.0]
# ['F#m(V+)', <music21.chord.Chord G#1 G#2>, 15.0]
# [None, <music21.note.Note C#>, 15.5]
# [None, <music21.chord.Chord E#3 B3 C#4>, 16.0]
# [None, <music21.note.Note B>, 16.5]
# ['I', <music21.note.Note B>, 17.0]
# [None, <music21.chord.Chord F#1 F#2>, 17.0]
# [None, <music21.note.Note A>, 18.0]
# [None, <music21.chord.Chord C#3 C#4>, 18.0]
# ['DimVII', <music21.chord.Chord E#3 D4>, 19.0]
# [None, <music21.note.Note B>, 19.0]
# [None, <music21.note.Note G#>, 19.5]
# [None, <music21.note.Note G#>, 20.0]
# [None, <music21.chord.Chord C#3 C#4>, 20.0]
# [None, <music21.note.Note F#>, 20.333333333333332]
# [None, <music21.note.Note E#>, 20.833333333333332]
# [None, <music21.note.Note E#>, 21.0]
# [None, <music21.note.Note F#>, 21.0]
# [None, <music21.note.Note F#>, 22.0]
# [None, <music21.chord.Chord C#3 A3>, 22.0]
# ['EM(V)', <music21.note.Note D#>, 23.0]
# [None, <music21.note.Note A#>, 23.5]
# [None, <music21.note.Note B>, 24.0]
# [None, <music21.chord.Chord B2 F#3 A3>, 24.0]
# [None, <music21.note.Note A>, 24.5]
# ['I', <music21.note.Note G#>, 25.0]
# [None, <music21.note.Note E>, 25.0]
# [None, <music21.note.Note D#>, 26.0]
# [None, <music21.chord.Chord B2 G#3>, 26.0]
# [None, <music21.note.Note E>, 26.5]
# [None, <music21.note.Note D#>, 27.0]
# [None, <music21.note.Note C#>, 27.0]
# [None, <music21.note.Note E>, 27.333333333333332]
# [None, <music21.note.Note D#>, 27.666666666666668]
# [None, <music21.note.Note E>, 28.0]
# [None, <music21.chord.Chord E3 F#3 A#3>, 28.0]
# [None, <music21.note.Note F#>, 28.333333333333332]
# [None, <music21.note.Note C#>, 28.666666666666668]
# [None, <music21.note.Note E>, 29.0]
# [None, <music21.note.Note B>, 29.0]
# [None, <music21.note.Note B>, 30.0]
# [None, <music21.note.Note G#>, 30.0]
# ['V', <music21.note.Note D#>, 31.0]
# [None, <music21.note.Note F#>, 31.0]
# [None, <music21.note.Note D#>, 31.333333333333332]
# [None, <music21.note.Note C#>, 31.833333333333332]
# [None, <music21.note.Note C#>, 32.0]
# [None, <music21.chord.Chord B3 D#4 A4>, 32.0]
# [None, <music21.note.Note B>, 32.333333333333336]
# [None, <music21.note.Note A>, 32.666666666666664]
# ['VI', <music21.note.Note G#>, 33.0]
# [None, <music21.note.Note E>, 33.0]
# [None, <music21.chord.Chord E3 G#3 C#4>, 34.0]
# [None, <music21.note.Note A>, 34.5]
# ['I', <music21.note.Note B>, 35.0]
# [None, <music21.chord.Chord B2 G#3 B3>, 35.0]
# [None, <music21.note.Note E>, 35.25]
# [None, <music21.note.Note F#>, 35.5]
# [None, <music21.note.Note G#>, 35.75]
# [None, <music21.note.Note F#>, 36.0]
# [None, <music21.chord.Chord B3 E4 G#4>, 36.0]
# [None, <music21.note.Note E>, 36.166666666666664]
# [None, <music21.note.Note B>, 36.333333333333336]
# [None, <music21.note.Note C#>, 36.5]
# [None, <music21.note.Note G#>, 36.666666666666664]
# [None, <music21.note.Note C#>, 36.833333333333336]
# ['V', <music21.note.Note B>, 37.0]
# [None, <music21.note.Note B>, 37.0]
# [None, <music21.chord.Chord F#3 D#4>, 38.0]
# [None, <music21.note.Note F#>, 39.0]
# [None, <music21.chord.Chord A3 D#4>, 39.0]
# [None, <music21.chord.Chord B#1 B#2>, 40.0]
# [None, <music21.note.Note G#>, 40.5]
# ['VI', <music21.note.Note E>, 41.0]
# [None, <music21.chord.Chord C#2 C#3>, 41.0]
# [None, <music21.chord.Chord E3 G#3 C#4>, 42.0]
# ['AM(V)', <music21.note.Note F#>, 43.0]
# [None, <music21.chord.Chord B1 B2>, 43.0]
# [None, <music21.note.Note G#>, 43.75]
# [None, <music21.note.Note A>, 44.0]
# [None, <music21.chord.Chord E3 G#3 D4>, 44.0]
# [None, <music21.note.Note B>, 44.5]
# ['I', <music21.note.Note C#>, 45.0]
# [None, <music21.chord.Chord A1 A2>, 45.0]
# [None, <music21.chord.Chord E3 C#4>, 46.0]
# ['BM(IV)', <music21.chord.Chord G1 G2>, 47.0]
# [None, <music21.note.Note C#>, 47.5]
# [None, <music21.chord.Chord E3 B3 E4>, 48.0]
# [None, <music21.note.Note B>, 48.5]
# [None, <music21.note.Note A#>, 49.0]
# [None, <music21.note.Note B>, 49.0]
# [None, <music21.note.Note C#>, 49.0]
# ['V', <music21.note.Note B>, 49.0]
# [None, <music21.chord.Chord F#1 F#2>, 49.0]
# [None, <music21.note.Note A#>, 50.0]
# [None, <music21.chord.Chord F#3 C#4 E4>, 50.0]
# ['II', <music21.chord.Chord E1 E2>, 51.0]
# [None, <music21.note.Note B>, 51.5]
# [None, <music21.note.Note C#>, 52.0]
# [None, <music21.chord.Chord G#3 C#4 G#4>, 52.0]
# [None, <music21.note.Note C##>, 52.5]
# ['G#m(V+)', <music21.note.Note D#>, 53.0]
# [None, <music21.chord.Chord D#1 D#2>, 53.0]
# [None, <music21.chord.Chord A#3 C#4 F##4>, 54.0]
# [None, <music21.note.Note C#>, 54.5]
# ['I', <music21.note.Note A#>, 55.0]
# [None, <music21.chord.Chord G#2 D#3 B3>, 55.0]
# [None, <music21.note.Note B>, 55.5]
# ['F#M(V)', <music21.note.Note C#>, 56.0]
# [None, <music21.chord.Chord E#2 C#3 B3>, 56.0]
# [None, <music21.note.Note G#>, 56.75]
# ['I', <music21.note.Note G#>, 57.0]
# [None, <music21.chord.Chord F#1 F#2>, 57.0]
# [None, <music21.note.Note F#>, 58.0]
# [None, <music21.chord.Chord F#3 B3 E4>, 58.0]
# ['VI', <music21.note.Note F#>, 59.0]
# [None, <music21.note.Note F#>, 59.0]
# [None, <music21.note.Note B>, 59.5]
# [None, <music21.note.Note D#>, 60.0]
# [None, <music21.chord.Chord F#3 A#3 D#4>, 60.0]
# [None, <music21.note.Note C#>, 60.75]
# ['BM(V)', <music21.note.Note A#>, 61.0]
# [None, <music21.note.Note B>, 61.0]
# [None, <music21.chord.Chord F#3 C#4 E4>, 62.0]
# ['I', <music21.note.Note B>, 63.0]
# [None, <music21.note.Note B>, 63.0]
# [None, <music21.chord.Chord F#3 B3 D#4>, 64.0]
# ['F#m(dimVII)', <music21.note.Note G#>, 65.0]
# [None, <music21.note.Note D>, 65.0]
# [None, <music21.chord.Chord F#3 B3 D4>, 66.0]
# [None, <music21.note.Note A>, 66.5]
# ['II', <music21.note.Note B>, 67.0]
# [None, <music21.note.Note G#>, 67.0]
# [None, <music21.note.Note C#>, 67.5]
# [None, <music21.note.Note E>, 68.0]
# [None, <music21.chord.Chord F#3 B3 F#4>, 68.0]
# [None, <music21.note.Note D>, 68.5]
# ['V+', <music21.note.Note E#>, 69.0]
# [None, <music21.chord.Chord C#2 C#3>, 69.0]
# [None, <music21.chord.Chord C#3 G#3 B3>, 70.0]
# ['I', <music21.note.Note F#>, 71.0]
# [None, <music21.chord.Chord F#1 F#2>, 71.0]
# [None, <music21.chord.Chord C#3 F#3 A3>, 72.0]
# ['G#m(IV)', <music21.note.Note A#>, 73.0]
# [None, <music21.chord.Chord E2 E3>, 73.0]
# [None, <music21.chord.Chord G#3 C#4>, 74.0]
# [None, <music21.note.Note B>, 74.5]
# ['II', <music21.note.Note C#>, 75.0]
# [None, <music21.chord.Chord A#1 A#2>, 75.0]
# [None, <music21.note.Note D#>, 75.5]
# [None, <music21.note.Note F#>, 76.0]
# [None, <music21.chord.Chord G#3 C#4>, 76.0]
# [None, <music21.note.Note E>, 76.5]
# ['V+7', <music21.note.Note F##>, 77.0]
# [None, <music21.chord.Chord D#2 D#3>, 77.0]
# [None, <music21.chord.Chord A#3 C#4>, 78.0]
# ['F#m(IV)', <music21.note.Note G#>, 79.0]
# [None, <music21.note.Note D>, 79.0]
# [None, <music21.note.Note D>, 79.0]
# [None, <music21.note.Note A>, 79.5]
# [None, <music21.note.Note C#>, 80.0]
# [None, <music21.chord.Chord F#3 B3>, 80.0]
# [None, <music21.note.Note B>, 80.5]
# ['V+7', <music21.note.Note E#>, 81.0]
# [None, <music21.note.Note C#>, 81.0]
# [None, <music21.note.Note C#>, 81.0]
# [None, <music21.chord.Chord G#3 B3>, 82.0]
# ['Em(IV)', <music21.note.Note F#>, 83.0]
# [None, <music21.note.Note C>, 83.0]
# [None, <music21.note.Note C>, 83.0]
# [None, <music21.note.Note G>, 83.5]
# [None, <music21.note.Note B>, 84.0]
# [None, <music21.chord.Chord E3 A3>, 84.0]
# [None, <music21.note.Note A>, 84.5]
# ['V+7', <music21.note.Note A>, 85.0]
# [None, <music21.note.Note B>, 85.0]
# [None, <music21.note.Note B>, 85.0]
# [None, <music21.note.Note G>, 86.0]
# [None, <music21.chord.Chord F#3 A3>, 86.0]
# [None, <music21.note.Note F#>, 86.375]
# [None, <music21.note.Note E>, 86.5]
# [None, <music21.note.Note D#>, 86.75]
# ['II', <music21.note.Note D#>, 87.0]
# [None, <music21.chord.Chord A3 C4>, 87.0]
# [None, <music21.chord.Chord G3 B3>, 88.0]
# [None, <music21.chord.Chord F#3 A3>, 88.5]
# [None, <music21.note.Note E>, 89.0]
# ['I', <music21.note.Note G>, 89.0]
# [None, <music21.note.Note B>, 89.0]
# [None, <music21.note.Note G>, 90.0]
# [None, <music21.chord.Chord B2 G3>, 90.0]
# [None, <music21.note.Note E>, 90.16666666666667]
# [None, <music21.note.Note C>, 90.33333333333333]
# [None, <music21.note.Note G>, 90.5]
# [None, <music21.note.Note E>, 90.66666666666667]
# [None, <music21.note.Note C>, 90.83333333333333]
# ['GerVI', <music21.note.Note G>, 91.0]
# [None, <music21.chord.Chord A#3 E4>, 91.0]
# [None, <music21.note.Note A>, 91.0625]
# [None, <music21.note.Note G>, 91.125]
# [None, <music21.note.Note A>, 91.1875]
# [None, <music21.note.Note G>, 91.25]
# [None, <music21.note.Note A>, 91.3125]
# [None, <music21.note.Note G>, 91.375]
# [None, <music21.note.Note A>, 91.4375]
# [None, <music21.note.Note G>, 91.5]
# [None, <music21.note.Note A>, 91.5625]
# [None, <music21.note.Note G>, 91.625]
# [None, <music21.note.Note A>, 91.66666666666667]
# [None, <music21.note.Note G>, 91.70833333333333]
# [None, <music21.note.Note F#>, 91.75]
# [None, <music21.note.Note E>, 91.875]
# ['I', <music21.note.Note G>, 92.0]
# [None, <music21.note.Note B>, 92.0]
# [None, <music21.note.Note A#>, 92.75]
# ['EM(V)', <music21.note.Note B>, 93.0]
# [None, <music21.note.Note B>, 93.0]
# [None, <music21.note.Note D#>, 94.0]
# [None, <music21.note.Note F#>, 94.0]
# [None, <music21.note.Note C#>, 95.0]
# [None, <music21.note.Note A>, 95.0]
# [None, <music21.note.Note D#>, 95.5]
# [None, <music21.note.Note E>, 96.0]
# [None, <music21.note.Note C#>, 96.0]
# [None, <music21.note.Note B>, 96.5]
# [None, <music21.note.Note F#>, 96.75]
# [None, <music21.note.Note G#>, 97.0]
# [None, <music21.note.Note E>, 97.0]
# [None, <music21.chord.Chord E3 G#3 C#4>, 98.0]
# [None, <music21.note.Note A>, 98.5]
# [None, <music21.note.Note B>, 99.0]
# [None, <music21.chord.Chord B2 G#3 B3>, 99.0]
# [None, <music21.note.Note E>, 99.11111111111111]
# [None, <music21.note.Note F#>, 99.22222222222223]
# [None, <music21.note.Note G#>, 99.33333333333333]
# [None, <music21.note.Note B>, 99.44444444444444]
# [None, <music21.note.Note E>, 99.55555555555556]
# [None, <music21.note.Note F#>, 99.66666666666667]
# [None, <music21.note.Note G#>, 99.77777777777777]
# [None, <music21.note.Note F#>, 99.88888888888889]
# [None, <music21.note.Note E>, 100.0]
# [None, <music21.chord.Chord B3 E4 G#4>, 100.0]
# [None, <music21.note.Note B>, 100.11111111111111]
# [None, <music21.note.Note G#>, 100.22222222222223]
# [None, <music21.note.Note F#>, 100.33333333333333]
# [None, <music21.note.Note E>, 100.44444444444444]
# [None, <music21.note.Note B>, 100.55555555555556]
# [None, <music21.note.Note C#>, 100.66666666666667]
# [None, <music21.note.Note G#>, 100.77777777777777]
# [None, <music21.note.Note C#>, 100.88888888888889]
# ['V', <music21.note.Note B>, 101.0]
# [None, <music21.note.Note B>, 101.0]
# [None, <music21.chord.Chord B2 A3>, 102.0]
# [None, <music21.note.Note F#>, 103.0]
# [None, <music21.chord.Chord A3 D#4>, 103.0]
# [None, <music21.note.Note B>, 104.0]
# [None, <music21.note.Note G>, 104.5]
# ['CM(VI)', <music21.note.Note E>, 105.0]
# [None, <music21.note.Note C>, 105.0]
# [None, <music21.chord.Chord E3 A3>, 106.0]
# [None, <music21.note.Note F>, 106.5]
# ['I', <music21.note.Note G>, 107.0]
# [None, <music21.chord.Chord G2 G3>, 107.0]
# [None, <music21.note.Note B>, 107.5]
# [None, <music21.note.Note C>, 108.0]
# [None, <music21.chord.Chord G3 E4>, 108.0]
# [None, <music21.note.Note A>, 108.5]
# ['V', <music21.note.Note G>, 109.0]
# [None, <music21.note.Note G>, 109.0]
# [None, <music21.chord.Chord G2 F3>, 110.0]
# [None, <music21.note.Note D>, 111.0]
# [None, <music21.chord.Chord F3 B3>, 111.0]
# [None, <music21.note.Note G>, 112.0]
# [None, <music21.note.Note E>, 112.5]
# ['GerVI', <music21.note.Note C#>, 113.0]
# [None, <music21.note.Note G>, 113.0]
# [None, <music21.note.Note G>, 113.0]
# [None, <music21.chord.Chord E3 A#3>, 114.0]
# [None, <music21.note.Note C#>, 115.0]
# [None, <music21.chord.Chord F#1 F#2>, 115.0]
# [None, <music21.note.Note D#>, 115.5]
# [None, <music21.note.Note E>, 116.0]
# [None, <music21.chord.Chord E1 E2>, 116.0]
# [None, <music21.note.Note E#>, 116.5]
# ['V', <music21.note.Note F#>, 117.0]
# [None, <music21.chord.Chord D#1 D#2>, 117.0]
# [None, <music21.note.Note B>, 118.0]
# [None, <music21.chord.Chord B2 A3>, 118.0]
# ['I', <music21.note.Note G#>, 119.0]
# [None, <music21.chord.Chord E1 E2>, 119.0]
# [None, <music21.chord.Chord E3 G#3 D4>, 120.0]
# ['II', <music21.note.Note G#>, 121.0]
# [None, <music21.chord.Chord A1 A2>, 121.0]
# [None, <music21.note.Note C#>, 121.25]
# [None, <music21.note.Note G#>, 121.5]
# [None, <music21.note.Note F#>, 121.66666666666667]
# [None, <music21.note.Note C#>, 121.83333333333333]
# [None, <music21.note.Note G#>, 122.0]
# [None, <music21.chord.Chord F#3 C#4 E4>, 122.0]
# [None, <music21.note.Note F#>, 122.08333333333333]
# [None, <music21.note.Note C#>, 122.16666666666667]
# [None, <music21.note.Note G#>, 122.25]
# [None, <music21.note.Note F#>, 122.33333333333333]
# [None, <music21.note.Note C#>, 122.41666666666667]
# [None, <music21.note.Note A>, 122.5]
# [None, <music21.note.Note F#>, 122.6]
# [None, <music21.note.Note C#>, 122.7]
# [None, <music21.note.Note A>, 122.8]
# [None, <music21.note.Note G#>, 122.9]
# ['V', <music21.note.Note F#>, 123.0]
# [None, <music21.chord.Chord B1 B2>, 123.0]
# [None, <music21.note.Note G#>, 123.08333333333333]
# [None, <music21.note.Note F#>, 123.16666666666667]
# [None, <music21.note.Note G#>, 123.25]
# [None, <music21.note.Note F#>, 123.33333333333333]
# [None, <music21.note.Note G#>, 123.41666666666667]
# [None, <music21.note.Note F#>, 123.5]
# [None, <music21.note.Note G#>, 123.58333333333333]
# [None, <music21.note.Note F#>, 123.66666666666667]
# [None, <music21.note.Note G#>, 123.72083333333333]
# [None, <music21.note.Note F#>, 123.775]
# [None, <music21.note.Note E#>, 123.83333333333333]
# [None, <music21.note.Note F#>, 123.95833333333333]
# [None, <music21.note.Note G#>, 124.0]
# [None, <music21.chord.Chord A3 D#4>, 124.0]
# [None, <music21.note.Note B>, 124.75]
# ['I', <music21.chord.Chord G#3 E4>, 125.0]
# [None, <music21.note.Note E>, 125.0]
# [None, <music21.note.Note C#>, 125.5]
# [None, <music21.note.Note A#>, 125.75]
# [None, <music21.note.Note C#>, 126.0]
# [None, <music21.note.Note B>, 126.25]
# [None, <music21.note.Note E>, 126.5]
# [None, <music21.note.Note D#>, 126.75]
# [None, <music21.note.Note F#>, 127.0]
# [None, <music21.note.Note E>, 127.25]
# [None, <music21.note.Note G#>, 127.5]
# [None, <music21.note.Note F##>, 127.75]
# [None, <music21.note.Note E>, 128.0]
# [None, <music21.note.Note A>, 128.0]
# [None, <music21.note.Note G#>, 128.25]
# [None, <music21.note.Note F#>, 128.5]
# [None, <music21.note.Note F#>, 128.75]
# [None, <music21.note.Note E>, 128.75]
# ['VI', <music21.chord.Chord G#3 E4 G#4>, 129.0]
# [None, <music21.note.Note D#>, 129.0]
# [None, <music21.note.Note D#>, 129.0]
# [None, <music21.note.Note C#>, 129.5]
# [None, <music21.note.Note G#>, 129.75]
# [None, <music21.note.Note C#>, 130.0]
# [None, <music21.note.Note C#>, 130.0]
# [None, <music21.note.Note B#>, 130.25]
# [None, <music21.note.Note D#>, 130.5]
# [None, <music21.note.Note C#>, 130.75]
# [None, <music21.note.Note E>, 131.0]
# [None, <music21.note.Note D#>, 131.25]
# [None, <music21.note.Note F#>, 131.5]
# [None, <music21.note.Note E>, 131.75]
# [None, <music21.note.Note E>, 132.0]
# [None, <music21.note.Note C#>, 132.0]
# [None, <music21.note.Note A>, 132.0]
# [None, <music21.note.Note G#>, 132.25]
# [None, <music21.note.Note F#>, 132.5]
# [None, <music21.note.Note F#>, 132.5]
# [None, <music21.note.Note G#>, 132.75]
# [None, <music21.note.Note E>, 132.75]
# ['BM(V)', <music21.chord.Chord E4 G#4>, 133.0]
# [None, <music21.note.Note A#>, 133.0]
# [None, <music21.note.Note F#>, 133.0]
# [None, <music21.note.Note B#>, 133.5]
# [None, <music21.note.Note C#>, 133.75]
# [None, <music21.note.Note E>, 134.0]
# [None, <music21.note.Note D#>, 134.25]
# [None, <music21.note.Note F#>, 134.5]
# [None, <music21.note.Note E>, 134.75]
# [None, <music21.chord.Chord D#4 F#4>, 135.0]
# [None, <music21.note.Note G#>, 135.0]
# [None, <music21.note.Note C#>, 135.5]
# [None, <music21.note.Note D#>, 135.75]
# [None, <music21.chord.Chord C#4 E4>, 136.0]
# [None, <music21.note.Note F#>, 136.0]
# [None, <music21.note.Note E>, 136.25]
# [None, <music21.note.Note G#>, 136.5]
# [None, <music21.note.Note F#>, 136.75]
# ['EM(IV)', <music21.note.Note C#>, 137.0]
# [None, <music21.note.Note F#>, 137.0]
# [None, <music21.note.Note A>, 137.0]
# [None, <music21.note.Note E>, 137.0]
# [None, <music21.note.Note D#>, 137.25]
# [None, <music21.note.Note C#>, 137.5]
# [None, <music21.note.Note E>, 137.75]
# [None, <music21.note.Note B>, 138.0]
# [None, <music21.note.Note D#>, 138.0]
# [None, <music21.note.Note C#>, 138.25]
# [None, <music21.note.Note B>, 138.5]
# [None, <music21.note.Note D#>, 138.75]
# [None, <music21.note.Note E>, 139.0]
# [None, <music21.note.Note A>, 139.0]
# [None, <music21.note.Note C#>, 139.0]
# [None, <music21.note.Note B>, 139.25]
# [None, <music21.note.Note A#>, 139.5]
# [None, <music21.note.Note C#>, 139.75]
# ['V', <music21.note.Note F#>, 140.0]
# [None, <music21.note.Note D#>, 140.0]
# [None, <music21.note.Note B>, 140.0]
# [None, <music21.note.Note F#>, 140.25]
# [None, <music21.note.Note G#>, 140.5]
# [None, <music21.note.Note C#>, 140.5]
# [None, <music21.note.Note A>, 140.75]
# [None, <music21.note.Note B>, 140.75]
# ['IV', <music21.chord.Chord C#4 A4>, 141.0]
# [None, <music21.note.Note E>, 141.0]
# [None, <music21.note.Note E>, 141.0]
# ['I', <music21.chord.Chord B3 G#4>, 141.5]
# [None, <music21.note.Note B>, 141.75]
# [None, <music21.note.Note D#>, 142.0]
# [None, <music21.note.Note C#>, 142.25]
# [None, <music21.note.Note E>, 142.5]
# [None, <music21.note.Note D#>, 142.75]
# [None, <music21.note.Note F#>, 143.0]
# [None, <music21.note.Note E>, 143.25]
# [None, <music21.note.Note E>, 143.5]
# [None, <music21.note.Note E>, 143.5]
# [None, <music21.note.Note G#>, 143.5]
# [None, <music21.note.Note F#>, 143.75]
# [None, <music21.note.Note E>, 144.0]
# [None, <music21.note.Note G#>, 144.0]
# [None, <music21.note.Note A>, 144.0]
# [None, <music21.note.Note G#>, 144.25]
# [None, <music21.note.Note F#>, 144.5]
# [None, <music21.note.Note E>, 144.75]
# [None, <music21.note.Note E>, 144.75]
# ['VI', <music21.note.Note E>, 145.0]
# [None, <music21.note.Note D#>, 145.0]
# [None, <music21.note.Note D#>, 145.0]
# [None, <music21.note.Note C#>, 145.5]
# [None, <music21.note.Note G#>, 145.75]
# [None, <music21.note.Note F#>, 146.0]
# [None, <music21.note.Note D#>, 146.0]
# [None, <music21.note.Note E>, 146.25]
# [None, <music21.note.Note C#>, 146.25]
# [None, <music21.note.Note C#>, 146.25]
# [None, <music21.note.Note C#>, 146.5]
# [None, <music21.note.Note E>, 146.5]
# [None, <music21.note.Note G#>, 146.75]
# [None, <music21.note.Note D#>, 146.75]
# ['II', <music21.note.Note G#>, 147.0]
# [None, <music21.note.Note F#>, 147.0]
# [None, <music21.note.Note E>, 147.25]
# [None, <music21.note.Note F#>, 147.5]
# [None, <music21.note.Note A>, 147.5]
# [None, <music21.note.Note E>, 147.75]
# [None, <music21.note.Note G#>, 147.75]
# [None, <music21.note.Note E>, 148.0]
# [None, <music21.note.Note F##>, 148.0]
# [None, <music21.note.Note G#>, 148.25]
# [None, <music21.note.Note F#>, 148.5]
# [None, <music21.note.Note E>, 148.5]
# [None, <music21.note.Note F##>, 148.75]
# [None, <music21.note.Note C#>, 148.75]
# [None, <music21.note.Note F##>, 149.0]
# ['G#M(I)', <music21.note.Note G#>, 149.0]
# [None, <music21.chord.Chord B#3 D#4>, 149.0]
# [None, <music21.note.Note G#>, 149.0]
# [None, <music21.note.Note D#>, 149.25]
# [None, <music21.note.Note G#>, 149.5]
# [None, <music21.note.Note B#>, 149.75]
# ['DimVII', <music21.chord.Chord F##3 C#4>, 150.0]
# [None, <music21.note.Note E>, 150.25]
# [None, <music21.note.Note E>, 150.25]
# [None, <music21.note.Note A>, 150.5]
# [None, <music21.chord.Chord C#5 E5>, 150.75]
# ['I', <music21.chord.Chord B#4 D#5>, 151.0]
# [None, <music21.note.Note G#>, 151.0]
# [None, <music21.note.Note D#>, 151.25]
# [None, <music21.chord.Chord D#4 G#4>, 151.5]
# [None, <music21.note.Note G#>, 151.5]
# [None, <music21.note.Note B#>, 151.75]
# ['DimVI', <music21.chord.Chord F##3 C#4>, 152.0]
# [None, <music21.note.Note E>, 152.25]
# [None, <music21.note.Note E>, 152.25]
# [None, <music21.note.Note A>, 152.5]
# [None, <music21.chord.Chord C#5 E5>, 152.75]
# ['C#m(V+7)', <music21.note.Note D#>, 153.0]
# [None, <music21.note.Note B#>, 153.0]
# [None, <music21.note.Note G#>, 153.0]
# [None, <music21.note.Note G#>, 153.25]
# [None, <music21.note.Note D#>, 153.5]
# [None, <music21.note.Note D#>, 153.5]
# [None, <music21.note.Note B#>, 153.75]
# [None, <music21.note.Note F#>, 154.0]
# [None, <music21.note.Note A>, 154.25]
# [None, <music21.note.Note B#>, 154.5]
# [None, <music21.note.Note A>, 154.875]
# [None, <music21.note.Note A>, 155.0]
# [None, <music21.note.Note D#>, 155.25]
# [None, <music21.note.Note F#>, 155.5]
# [None, <music21.note.Note A>, 155.75]
# [None, <music21.note.Note D#>, 156.0]
# [None, <music21.note.Note F#>, 156.25]
# [None, <music21.note.Note A>, 156.5]
# [None, <music21.note.Note C#>, 156.75]
# [None, <music21.note.Note E>, 157.0]
# [None, <music21.chord.Chord F#3 A3>, 157.25]
# [None, <music21.note.Note D#>, 157.5]
# [None, <music21.note.Note C#>, 157.75]
# [None, <music21.chord.Chord F#3 A3>, 157.75]
# [None, <music21.note.Note B#>, 158.0]
# [None, <music21.note.Note D#>, 158.0]
# [None, <music21.chord.Chord F#3 A3>, 158.25]
# [None, <music21.note.Note C#>, 158.5]
# [None, <music21.note.Note C#>, 158.5]
# [None, <music21.note.Note D#>, 158.75]
# [None, <music21.chord.Chord F#3 A3>, 158.75]
# ['V+7', <music21.note.Note D#>, 159.0]
# [None, <music21.chord.Chord F#3 G#3>, 159.0]
# [None, <music21.note.Note B#>, 159.0]
# [None, <music21.note.Note F#>, 159.25]
# [None, <music21.note.Note G#>, 159.25]
# [None, <music21.note.Note F##>, 159.5]
# [None, <music21.note.Note G#>, 159.75]
# [None, <music21.note.Note F#>, 159.75]
# [None, <music21.note.Note G#>, 159.75]
# [None, <music21.note.Note A#>, 160.0]
# [None, <music21.note.Note G#>, 160.0]
# [None, <music21.note.Note G#>, 160.0]
# [None, <music21.note.Note B#>, 160.25]
# [None, <music21.note.Note F#>, 160.25]
# [None, <music21.note.Note G#>, 160.25]
# [None, <music21.note.Note C#>, 160.5]
# [None, <music21.note.Note A>, 160.5]
# [None, <music21.note.Note D#>, 160.75]
# [None, <music21.chord.Chord F#3 B#3>, 160.75]
# [None, <music21.note.Note G#>, 160.75]
# ['I', <music21.note.Note E>, 161.0]
# [None, <music21.chord.Chord F#3 B#3>, 161.0]
# [None, <music21.note.Note C#>, 161.0]
# [None, <music21.note.Note C#>, 161.0]
# [None, <music21.chord.Chord E3 C#4>, 161.25]
# [None, <music21.note.Note G#>, 161.25]
# [None, <music21.note.Note D#>, 161.5]
# [None, <music21.note.Note B#>, 161.5]
# [None, <music21.note.Note E>, 161.75]
# [None, <music21.chord.Chord G#3 C#4>, 161.75]
# [None, <music21.note.Note C#>, 161.75]
# ['IV', <music21.note.Note F#>, 162.0]
# [None, <music21.note.Note F#>, 162.0]
# [None, <music21.note.Note F#>, 162.0]
# [None, <music21.note.Note G#>, 162.25]
# [None, <music21.chord.Chord A3 C#4>, 162.25]
# [None, <music21.note.Note C#>, 162.25]
# [None, <music21.note.Note E>, 162.5]
# [None, <music21.note.Note G#>, 162.5]
# [None, <music21.note.Note F#>, 162.75]
# [None, <music21.chord.Chord A3 C#4>, 162.75]
# [None, <music21.note.Note F#>, 162.75]
# ['I', <music21.note.Note G#>, 163.0]
# [None, <music21.note.Note C#>, 163.0]
# [None, <music21.note.Note C#>, 163.0]
# [None, <music21.chord.Chord G#3 C#4 E4>, 163.25]
# [None, <music21.note.Note G#>, 163.25]
# [None, <music21.note.Note F#>, 163.5]
# [None, <music21.chord.Chord G#3 C#4 E4>, 163.75]
# [None, <music21.note.Note E>, 163.75]
# ['EM(V)', <music21.note.Note B>, 164.0]
# [None, <music21.note.Note D#>, 164.0]
# [None, <music21.chord.Chord A3 D#4 F#4>, 164.25]
# [None, <music21.note.Note C#>, 164.25]
# [None, <music21.note.Note B>, 164.5]
# [None, <music21.chord.Chord A3 B3 D#4>, 164.75]
# [None, <music21.note.Note F#>, 164.75]
# ['I', <music21.note.Note G#>, 165.0]
# [None, <music21.chord.Chord A3 B3 D#4>, 165.0]
# [None, <music21.note.Note B>, 165.0]
# [None, <music21.note.Note B>, 165.0]
# [None, <music21.chord.Chord A3 B3>, 165.25]
# [None, <music21.note.Note E>, 165.25]
# [None, <music21.note.Note F#>, 165.5]
# [None, <music21.note.Note D#>, 165.5]
# [None, <music21.note.Note E>, 165.75]
# [None, <music21.chord.Chord A3 B3>, 165.75]
# [None, <music21.note.Note G#>, 165.75]
# [None, <music21.note.Note D#>, 166.0]
# [None, <music21.note.Note G#>, 166.0]
# [None, <music21.chord.Chord A3 B3>, 166.25]
# [None, <music21.note.Note E>, 166.5]
# [None, <music21.note.Note F#>, 166.5]
# [None, <music21.note.Note F#>, 166.75]
# [None, <music21.chord.Chord A3 B3>, 166.75]
# [None, <music21.note.Note E>, 166.75]
# ['V', <music21.note.Note F#>, 167.0]
# [None, <music21.chord.Chord A3 B3>, 167.0]
# [None, <music21.note.Note D#>, 167.0]
# [None, <music21.note.Note B>, 167.25]
# [None, <music21.note.Note A>, 167.25]
# [None, <music21.note.Note C#>, 167.5]
# [None, <music21.note.Note E>, 167.5]
# [None, <music21.note.Note B>, 167.75]
# [None, <music21.note.Note A>, 167.75]
# [None, <music21.note.Note F#>, 167.75]
# [None, <music21.note.Note C#>, 168.0]
# [None, <music21.note.Note F#>, 168.0]
# [None, <music21.note.Note D#>, 168.25]
# [None, <music21.chord.Chord A3 B3>, 168.25]
# [None, <music21.note.Note B>, 168.25]
# [None, <music21.note.Note E>, 168.5]
# [None, <music21.note.Note C#>, 168.5]
# [None, <music21.note.Note F#>, 168.75]
# [None, <music21.chord.Chord A3 D#4>, 168.75]
# [None, <music21.note.Note B>, 168.75]
# ['VI', <music21.note.Note G#>, 169.0]
# [None, <music21.note.Note E>, 169.0]
# [None, <music21.chord.Chord G#3 C##4>, 169.25]
# [None, <music21.note.Note B>, 169.25]
# [None, <music21.note.Note F##>, 169.5]
# [None, <music21.note.Note E>, 169.5]
# [None, <music21.note.Note G#>, 169.75]
# [None, <music21.chord.Chord G#3 C##4>, 169.75]
# [None, <music21.note.Note E>, 169.75]
# ['G#m(V+7)', <music21.note.Note A#>, 170.0]
# [None, <music21.note.Note D#>, 170.0]
# [None, <music21.note.Note B>, 170.25]
# [None, <music21.chord.Chord C#4 D#4>, 170.25]
# [None, <music21.note.Note G#>, 170.25]
# [None, <music21.note.Note G#>, 170.5]
# [None, <music21.note.Note E#>, 170.5]
# [None, <music21.note.Note A#>, 170.75]
# [None, <music21.chord.Chord C#4 D#4>, 170.75]
# [None, <music21.note.Note F##>, 170.75]
# ['I', <music21.note.Note B>, 171.0]
# [None, <music21.note.Note G#>, 171.0]
# [None, <music21.chord.Chord D#4 G#4>, 171.25]
# [None, <music21.note.Note B>, 171.25]
# [None, <music21.note.Note A#>, 171.5]
# [None, <music21.chord.Chord D#4 G#4>, 171.75]
# [None, <music21.note.Note G#>, 171.75]
# ['V+7', <music21.note.Note D#>, 172.0]
# [None, <music21.note.Note F##>, 172.0]
# [None, <music21.chord.Chord C#4 A#4>, 172.25]
# [None, <music21.note.Note E>, 172.25]
# [None, <music21.note.Note D#>, 172.5]
# [None, <music21.chord.Chord C#4 F##4 A#4>, 172.75]
# [None, <music21.note.Note D#>, 172.75]
# ['I', <music21.note.Note B>, 173.0]
# [None, <music21.note.Note G#>, 173.0]
# [None, <music21.note.Note G#>, 173.0]
# [None, <music21.chord.Chord B3 D#4>, 173.25]
# [None, <music21.note.Note D#>, 173.25]
# [None, <music21.note.Note A#>, 173.5]
# [None, <music21.note.Note G#>, 173.75]
# [None, <music21.chord.Chord B3 D#4>, 173.75]
# [None, <music21.note.Note D#>, 173.75]
# ['V+7', <music21.note.Note A#>, 174.0]
# [None, <music21.note.Note D#>, 174.0]
# [None, <music21.note.Note D#>, 174.0]
# [None, <music21.chord.Chord C#4 D#4>, 174.25]
# [None, <music21.note.Note D#>, 174.25]
# [None, <music21.note.Note B>, 174.5]
# [None, <music21.note.Note F##>, 174.75]
# [None, <music21.chord.Chord C#4 D#4>, 174.75]
# [None, <music21.note.Note D#>, 174.75]
# ['I', <music21.note.Note G#>, 175.0]
# [None, <music21.note.Note G#>, 175.0]
# [None, <music21.note.Note G#>, 175.0]
# [None, <music21.chord.Chord B3 D#4>, 175.25]
# [None, <music21.note.Note D#>, 175.25]
# [None, <music21.note.Note F#>, 175.5]
# [None, <music21.note.Note E>, 175.5]
# [None, <music21.chord.Chord B3 D#4>, 175.75]
# [None, <music21.note.Note D#>, 175.75]
# ['V+7', <music21.note.Note A#>, 176.0]
# [None, <music21.note.Note C##>, 176.0]
# [None, <music21.chord.Chord C#4 D#4 F##4>, 176.25]
# [None, <music21.note.Note D#>, 176.25]
# [None, <music21.note.Note D#>, 176.5]
# [None, <music21.note.Note D#>, 176.5]
# [None, <music21.chord.Chord C#4 D#4>, 176.75]
# [None, <music21.note.Note D#>, 176.75]
# ['I', <music21.note.Note B>, 177.0]
# [None, <music21.note.Note G#>, 177.0]
# [None, <music21.note.Note G#>, 177.0]
# [None, <music21.chord.Chord B3 D#4>, 177.25]
# [None, <music21.note.Note D#>, 177.25]
# [None, <music21.note.Note A#>, 177.5]
# [None, <music21.note.Note G#>, 177.75]
# [None, <music21.chord.Chord B3 D#4>, 177.75]
# [None, <music21.note.Note D#>, 177.75]
# ['V+7', <music21.note.Note A#>, 178.0]
# [None, <music21.note.Note D#>, 178.0]
# [None, <music21.note.Note D#>, 178.0]
# [None, <music21.note.Note C#>, 178.25]
# [None, <music21.chord.Chord C#4 D#4>, 178.25]
# [None, <music21.note.Note D#>, 178.25]
# [None, <music21.note.Note B>, 178.5]
# [None, <music21.note.Note F##>, 178.75]
# [None, <music21.chord.Chord C#4 D#4>, 178.75]
# [None, <music21.note.Note D#>, 178.75]
# ['I', <music21.note.Note G#>, 179.0]
# [None, <music21.note.Note G#>, 179.0]
# [None, <music21.chord.Chord B3 D#4>, 179.25]
# [None, <music21.note.Note D#>, 179.25]
# ['V+7', <music21.note.Note B>, 179.5]
# [None, <music21.note.Note D#>, 179.5]
# [None, <music21.note.Note F##>, 179.75]
# [None, <music21.chord.Chord C#4 D#4>, 179.75]
# [None, <music21.note.Note D#>, 179.75]
# ['I', <music21.note.Note G#>, 180.0]
# [None, <music21.note.Note G#>, 180.0]
# [None, <music21.chord.Chord B3 D#4>, 180.25]
# [None, <music21.note.Note D#>, 180.25]
# ['V+7', <music21.note.Note B>, 180.5]
# [None, <music21.note.Note D#>, 180.5]
# [None, <music21.note.Note F##>, 180.75]
# [None, <music21.chord.Chord C#4 D#4>, 180.75]
# [None, <music21.note.Note D#>, 180.75]
# ['I', <music21.note.Note G#>, 181.0]
# [None, <music21.note.Note G#>, 181.0]
# [None, <music21.chord.Chord B3 D#4>, 181.25]
# [None, <music21.note.Note D#>, 181.25]
# ['F#m(V+7)', <music21.note.Note A>, 181.5]
# [None, <music21.note.Note C#>, 181.5]
# [None, <music21.note.Note E#>, 181.75]
# [None, <music21.chord.Chord B3 C#4>, 181.75]
# [None, <music21.note.Note C#>, 181.75]
# ['I', <music21.note.Note F#>, 182.0]
# [None, <music21.note.Note F#>, 182.0]
# [None, <music21.chord.Chord A3 C#4>, 182.25]
# [None, <music21.note.Note C#>, 182.25]
# ['V+7', <music21.note.Note A>, 182.5]
# [None, <music21.note.Note C#>, 182.5]
# [None, <music21.note.Note E#>, 182.75]
# [None, <music21.chord.Chord B3 C#4>, 182.75]
# [None, <music21.note.Note C#>, 182.75]
# ['I', <music21.note.Note F#>, 183.0]
# [None, <music21.note.Note F#>, 183.0]
# [None, <music21.chord.Chord A3 C#4>, 183.25]
# [None, <music21.note.Note C#>, 183.25]
# ['V+7', <music21.note.Note A>, 183.5]
# [None, <music21.note.Note C#>, 183.5]
# [None, <music21.note.Note E#>, 183.75]
# [None, <music21.chord.Chord B3 C#4>, 183.75]
# [None, <music21.note.Note C#>, 183.75]
# ['I', <music21.note.Note F#>, 184.0]
# [None, <music21.note.Note F#>, 184.0]
# [None, <music21.chord.Chord A3 C#4>, 184.25]
# [None, <music21.note.Note C#>, 184.25]
# ['Em(V+7)', <music21.note.Note G>, 184.5]
# [None, <music21.note.Note B>, 184.5]
# [None, <music21.note.Note D#>, 184.75]
# [None, <music21.note.Note A>, 184.75]
# [None, <music21.note.Note B>, 184.75]
# ['GerVI', <music21.chord.Chord G3 C4 E4>, 185.0]
# [None, <music21.note.Note A#>, 185.0]
# [None, <music21.note.Note A#>, 185.25]
# [None, <music21.note.Note E>, 185.5]
# [None, <music21.note.Note G>, 185.75]
# ['DimVII', <music21.note.Note F#>, 186.0]
# [None, <music21.note.Note A>, 186.25]
# [None, <music21.note.Note A>, 186.25]
# [None, <music21.note.Note C>, 186.5]
# [None, <music21.chord.Chord D#4 F#4>, 186.75]
# ['GerVI', <music21.chord.Chord E4 G4>, 187.0]
# [None, <music21.note.Note A#>, 187.0]
# [None, <music21.note.Note A#>, 187.25]
# [None, <music21.chord.Chord G3 C4>, 187.5]
# [None, <music21.note.Note E>, 187.5]
# [None, <music21.note.Note G>, 187.75]
# ['DimVII', <music21.note.Note F#>, 188.0]
# [None, <music21.note.Note A>, 188.25]
# [None, <music21.note.Note A>, 188.25]
# [None, <music21.note.Note C>, 188.5]
# [None, <music21.chord.Chord D#4 F#4>, 188.75]
# ['GerVI', <music21.chord.Chord E4 G4>, 189.0]
# [None, <music21.note.Note A#>, 189.0]
# [None, <music21.note.Note A#>, 189.25]
# [None, <music21.chord.Chord G3 C4>, 189.5]
# [None, <music21.note.Note E>, 189.5]
# [None, <music21.note.Note G>, 189.75]
# [None, <music21.note.Note C>, 190.0]
# [None, <music21.note.Note E>, 190.25]
# [None, <music21.note.Note G>, 190.5]
# [None, <music21.note.Note E>, 190.75]
# [None, <music21.note.Note D#>, 191.0]
# [None, <music21.note.Note B>, 191.0]
# [None, <music21.note.Note D>, 191.25]
# [None, <music21.note.Note C#>, 191.5]
# [None, <music21.note.Note C>, 191.75]
# [None, <music21.note.Note C>, 191.75]
# [None, <music21.note.Note B>, 192.0]
# [None, <music21.note.Note C#>, 192.0]
# [None, <music21.chord.Chord D4 G4 B-4>, 192.25]
# [None, <music21.note.Note D>, 192.25]
# [None, <music21.note.Note A>, 192.5]
# [None, <music21.note.Note D#>, 192.5]
# [None, <music21.note.Note E>, 192.57083333333333]
# [None, <music21.note.Note D#>, 192.6422619047619]
# [None, <music21.note.Note E>, 192.71369047619046]
# [None, <music21.chord.Chord B#3 F#4 A-4>, 192.75]
# [None, <music21.note.Note D#>, 192.78511904761905]
# [None, <music21.note.Note C##>, 193.07083333333333]
# [None, <music21.note.Note D#>, 193.19583333333333]

# %%
#main
current_key=None
Major=None
for e in b:
    if current_key is None:
        #fail-safe
        if e[1].lyric is None:
            continue
        print('start')
        e[1].addLyric('start')#every score should veriyf its start***
        current_key=e[1].lyric
        
        #identify major or minor
        if 'M' in current_key:
            Major=True        
        else:
            Major=False
                        
        #identify key name
        if Major:
            e[1].addLyric('trans->CM')
            current_key=current_key.split('M')[0]
        else:
            e[1].addLyric('trans->Am')
            current_key=current_key.split('m')[0]
         
    #check if key change
    elif e[1].lyric is not None and ('m' in e[1].lyric or 'M' in e[1].lyric) and '(' in e[1].lyric:  # '(' --> is just to make sure it is key change        
            
        #DEBUG
        #print(current_key,Major)
        #print(e[1].lyric)
        #print('----------------------')
        
        #check if key is different from previous key        
        if not((Major and 'M' in e[1].lyric and current_key==e[1].lyric.split('M')[0]) or (not Major and 'm' in e[1].lyric and current_key==e[1].lyric.split('m')[0])):
            #update key
            print('change key')
            current_key=e[1].lyric
            
            #identify major or minor
            if 'M' in current_key:
                Major=True
            else:
                Major=False
                
            #identify key name
            if Major:
                current_key=current_key.split('M')[0]
                e[1].addLyric('trans->CM')
            else:
                current_key=current_key.split('m')[0]
                e[1].addLyric('trans->Am')
            
            
    if Major:
        e[1].transpose(MtoC[current_key], inPlace=True)
    else:
        e[1].transpose(mtoA[current_key], inPlace=True)
# Out:
# start
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key
# change key

# %%
#save
GEX = musicxml.m21ToXml.GeneralObjectExporter(c)
out = GEX.parse()
with open("test.musicxml", "wb") as f:
        f.write(out)
# Out:
# ---------------------------------------------------------------------------
# DurationException                         Traceback (most recent call last)
# <ipython-input-10-44a690f32d33> in <module>
#       1 #save
#       2 GEX = musicxml.m21ToXml.GeneralObjectExporter(c)
# ----> 3 out = GEX.parse()
#       4 with open("test.musicxml", "wb") as f:
#       5         f.write(out)
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parse(self, obj)
#     375         outObj = self.fromGeneralObject(obj)
#     376         # TODO: set whether to do an additional score copy in submethods.
# --> 377         return self.parseWellformedObject(outObj)
#     378
#     379     def parseWellformedObject(self, sc):
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parseWellformedObject(self, sc)
#     383         '''
#     384         scoreExporter = ScoreExporter(sc)
# --> 385         scoreExporter.parse()
#     386         return scoreExporter.asBytes()
#     387
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parse(self)
#    1360
#    1361         if s.hasPartLikeStreams():
# -> 1362             self.parsePartlikeScore()
#    1363         else:
#    1364             self.parseFlatScore()
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parsePartlikeScore(self)
#    1540             pp = PartExporter(innerStream, parent=self)
#    1541             pp.spannerBundle = self.spannerBundle
# -> 1542             pp.parse()
#    1543             self.partExporterList.append(pp)
#    1544
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parse(self)
#    2352             measureExporter.spannerBundle = self.spannerBundle
#    2353             try:
# -> 2354                 mxMeasure = measureExporter.parse()
#    2355             except MusicXMLExportException as e:
#    2356                 e.measureNumber = str(m.number)
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parse(self)
#    2690         self.setLeftBarline()
#    2691         # BIG ONE
# -> 2692         self.mainElementsParse()
#    2693         # continue
#    2694         self.setRightBarline()
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in mainElementsParse(self)
#    2718
#    2719             # Assumes voices are flat...
# -> 2720             self.parseFlatElements(v, backupAfterwards=backupAfterwards)
#    2721
#    2722     def parseFlatElements(self, m, *, backupAfterwards=False):
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parseFlatElements(self, m, backupAfterwards)
#    2776
#    2777             for n in notesForLater:
# -> 2778                 self.parseOneElement(n)
#    2779
#    2780         if backupAfterwards:
#
# D:\anacnda\lib\site-packages\music21\musicxml\m21ToXml.py in parseOneElement(self, obj)
#    2806
#    2807         # turn inexpressible durations into complex durations (unless unlinked)
# -> 2808         if obj.duration.type == 'inexpressible':
#    2809             obj.duration.quarterLength = obj.duration.quarterLength
#    2810
#
# D:\anacnda\lib\site-packages\music21\duration.py in type(self)
#    2750         if self.linked is False:
#    2751             return self._unlinkedType
# -> 2752         elif len(self.components) == 1:
#    2753             return self.components[0].type
#    2754         elif len(self.components) > 1:
#
# D:\anacnda\lib\site-packages\music21\duration.py in components(self)
#    2297     def components(self):
#    2298         if self._componentsNeedUpdating:
# -> 2299             self._updateComponents()
#    2300         return tuple(self._components)
#    2301
#
# D:\anacnda\lib\site-packages\music21\duration.py in _updateComponents(self)
#    1646         if self.linked:
#    1647             try:
# -> 1648                 qlc = quarterConversion(self._qtrLength)
#    1649                 self.components = list(qlc.components)
#    1650                 if qlc.tuplet is not None:
#
# D:\anacnda\lib\site-packages\music21\duration.py in quarterConversion(qLen)
#     688     # 8 tied components was not enough.
#     689     # last resort: put one giant tuplet over it.
# --> 690     tuplet, component = quarterLengthToNonPowerOf2Tuplet(qLen)
#     691     return QuarterLengthConversion((component,), tuplet)
#     692
#
# D:\anacnda\lib\site-packages\music21\duration.py in quarterLengthToNonPowerOf2Tuplet(qLen)
#     394     # qFrac will always be in lowest terms
#     395
# --> 396     closestSmallerType, unused_match = quarterLengthToClosestType(qLen / qFrac.denominator)
#     397
#     398     tupletDuration = Duration(type=closestSmallerType)
#
# D:\anacnda\lib\site-packages\music21\duration.py in quarterLengthToClosestType(qLen)
#     293             return ('duplex-maxima', False)
#     294
# --> 295         raise DurationException('Cannot return types smaller than 2048th; '
#     296                                 + f'qLen was: {qLen}')
#     297
#
# DurationException: Cannot return types smaller than 2048th; qLen was: 1/1680
