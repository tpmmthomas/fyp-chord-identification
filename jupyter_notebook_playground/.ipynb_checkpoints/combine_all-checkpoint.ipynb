# %%
from music21 import *
import music21
import os
import glob
import re
import numpy as np
import math

# %%
def cal_offset(e):
    if e is None:
        return 0
    return e.offset+cal_offset(e.activeSite)

# %%
class Score_in_beat:
    
    def __init__(self):
        self.beat_list=[Beat()]
        
    #extract info from note and add to corrsponding beat
    def add_note(self,note):
        length=note.quarterLength
        start=cal_offset(note)
        end=start+length
        rounded_floor_start=math.floor(start)
        #loop until the note played to its end
        while start<end-0.000000000001:
            if len(self.beat_list)-1<rounded_floor_start:
                new_beat=rounded_floor_start-(len(self.beat_list)-1)
                #the input note maybe is a chord -> recurse all pitch inside
                for _ in range(new_beat):
                    self.beat_list.append(Beat())
            self.beat_list[rounded_floor_start].add_note(note,min(rounded_floor_start+1-start,end-start))
            start+=min(rounded_floor_start+1-start,end-start)
            rounded_floor_start=int(start)
            
    #add key to the first occurence of beat
    def add_key(self,note):
        assert(note.lyric is not None and '(' in note.lyric)
        key_change_beat=cal_offset(note)
        rounded_floor_key_change_beat=math.floor(key_change_beat)
        self.beat_list[rounded_floor_key_change_beat].add_key(note.lyric.split('(')[0])
        
    #onyl call once
    def infer_key(self):
        first_key_in_num=None
        first_key_full=None
        first_key_major=None
        #backtrack
        for e in self.beat_list:
            if e.key_full is not None:
                first_key_full=e.key_full
                first_key_in_num=e.key_in_num
                first_key_major=e.major
                break
        #bring forward
        for e in self.beat_list:
            if e.key_full is None:
                e.key_full=first_key_full
                e.key_in_num=first_key_in_num
                e.major=first_key_major
            else:
                first_key_full=e.key_full
                first_key_in_num=e.key_in_num
                first_key_major=e.major

# %%
key_mapping={
    'C':0,
    'D':2,
    'E':4,
    'F':5,
    'G':7,
    'A':9,
    'B':11
}
def key2num(k):  
    k=k.upper()
    num=key_mapping[k[0]]
    modifier=len(k)
    if modifier==1:
        return num
    elif k[1]=='#':
        return (num+(modifier-1))%12
    elif k[1]=='B' or k[1]=='-' or k[1]=='♭':
        return (num-(modifier-1))%12
    elif k[1]=='X':
        return (num+(modifier-1)*2)%12

# %%
class Beat:
    def __init__(self):
        self.notes = np.zeros((12,7))  #from C1 to C7
        self.total_duration = np.zeros((12,7))
        self.notes_occurences_count= np.zeros((12,7))
        self.key_full=None
        self.major=None
        self.key_in_num=None
        
    def add_note(self,note,duration):
        assert(duration<=1)
        pitches=note.pitches
        for pitch in pitches:
            pitch_idx=key2num(pitch.nameWithOctave[:-1])
            octave=int(pitch.nameWithOctave[-1])-1
            if octave<0:
                octave=0
            elif octave>6:
                octave=6
            self.notes[pitch_idx,octave]=1
            self.total_duration[pitch_idx,octave]+=duration
            self.notes_occurences_count[pitch_idx,octave]+=1
            
    def add_key(self,k):
        self.major = 'M' in k
        self.key_full=k
        k=k[:-1]
        self.key_in_num=key2num(k)

# %%
all_score_train=[]
all_score_test=[]
all_score=[]
files=["../musicxml(train)/*.mxl","../musicxml(test)/*.mxl"]
for piece in glob.glob(files[0]):
    all_score.append(piece)
    all_beat_train=Score_in_beat()
    all_score_train.append(all_beat_train)
    print('train',piece)
    chords = []
    notes = []
    c = converter.parse(piece)
    post = c.flat

    #extract note
    for note in post.notes:
        all_beat_train.add_note(note)
        if note.lyric is not None and '(' in note.lyric:
            all_beat_train.add_key(note)

    all_beat_train.infer_key()
for piece in glob.glob(files[1]):
    all_score.append(piece)
    all_beat_test=Score_in_beat()
    all_score_test.append(all_beat_test)
    print('test',piece)
    chords = []
    notes = []
    c = converter.parse(piece)
    post = c.flat

    #extract note
    for note in post.notes:
        all_beat_test.add_note(note)
        if note.lyric is not None and '(' in note.lyric:
            all_beat_test.add_key(note)

    all_beat_test.infer_key()
# Out:
# train ../musicxml(train)\Fugue_in_G_Minor.mxl
# train ../musicxml(train)\G_minor.mxl
# train ../musicxml(train)\Menuet_in_G_Minor.mxl
# train ../musicxml(train)\Minuet_in_F.mxl
# train ../musicxml(train)\Minuet_in_G_Major.mxl
# train ../musicxml(train)\Moonlight_Sonata_1st_Movement.mxl
# train ../musicxml(train)\Musette_in_D.mxl
# train ../musicxml(train)\Nocturne_in_B_Major.mxl
# train ../musicxml(train)\Nocturne_in_C#_Minor.mxl
# train ../musicxml(train)\Nocturne_in_Eb_Major.mxl
# train ../musicxml(train)\Nocturne_in_E_Minor.mxl
# train ../musicxml(train)\Nocturne_in_F#_Major.mxl
# train ../musicxml(train)\Nocturne_no._1.mxl
# train ../musicxml(train)\Nocturne_No._20_in_C#_Minor.mxl
# train ../musicxml(train)\Prélude_in_A_Major.mxl
# train ../musicxml(train)\Prélude_in_B_Major.mxl
# train ../musicxml(train)\Prélude_in_B_Minor.mxl
# train ../musicxml(train)\Prélude_in_B_Minor_op104a.mxl
# train ../musicxml(train)\Prélude_in_Db_Major.mxl
# train ../musicxml(train)\Prélude_in_E_Minor.mxl
# train ../musicxml(train)\Prélude_in_F#_Major.mxl
# train ../musicxml(train)\Prélude_in_G_Major.mxl
# train ../musicxml(train)\Solfeggietto_in_C_minor.mxl
# train ../musicxml(train)\sonata_no_1.mxl
# train ../musicxml(train)\Sonate_No._28.mxl
# train ../musicxml(train)\Sonate_No._28_1stmovt.mxl
# train ../musicxml(train)\Sonate_No._31.mxl
# train ../musicxml(train)\Sonatina_in_G.mxl
# train ../musicxml(train)\Spring_Waltz.mxl
# train ../musicxml(train)\Twinkle-Twinkle.mxl
# train ../musicxml(train)\Waltz.mxl
# train ../musicxml(train)\Waltz_in_Eb_Major.mxl
# train ../musicxml(train)\Étude_in_F_Major.mxl
# train ../musicxml(train)\Étude_in_F_Minor.mxl
# train ../musicxml(train)\Étude_in_Gb_Major.mxl
# train ../musicxml(train)\Étude_in_Gb_Major_Op25.mxl
# test ../musicxml(test)\Il_Vecchio_Castello.mxl
# test ../musicxml(test)\Piano_Sonata_No._11.mxl
# test ../musicxml(test)\Prélude_in_C_Minor.mxl
# test ../musicxml(test)\Waltz_in_A_Minor.mxl
# test ../musicxml(test)\Étude_in_C_Minor.mxl

# %%
#turns each beat to a vector
weight=[1.35,1.25,0.9,0.8,0.9,1,1.2]

trainX=[]
trainY=[]
for e in all_score_train:
    tempX=[]
    tempY=[]
    count=0
    for beat in e.beat_list:
        value=beat.total_duration*beat.notes_occurences_count
        if np.sum(value)!=0:
            value/=np.sum(value)
            value*=weight
            value=value.sum(axis=1)
            #value=value.reshape((-1))
            value/=value.sum()
        else:
            value=np.zeros((12))
            
        assert(len(value)==12)
        tempX.append(value)
        
        prepare_y=np.zeros((13,1))
        prepare_y[-1]=beat.major*1
        prepare_y[beat.key_in_num]=1
        assert(len(prepare_y)==13)
        tempY.append(prepare_y)
        count+=1
    trainX.append(tempX)
    trainY.append(tempY)

testX=[]
testY=[]
for e in all_score_test:
    tempX=[]
    tempY=[]
    count=0
    for beat in e.beat_list:
        value=beat.total_duration*beat.notes_occurences_count
        if np.sum(value)!=0:
            value/=np.sum(value)
            value*=weight
            value=value.sum(axis=1)
            #value=value.reshape((-1))
            value/=value.sum()
        else:
            value=np.zeros((12))
            
        assert(len(value)==12)
        tempX.append(value)
        
        prepare_y=np.zeros((13,1))
        prepare_y[-1]=beat.major*1
        prepare_y[beat.key_in_num]=1
        assert(len(prepare_y)==13)
        tempY.append(prepare_y)
        count+=1
    testX.append(tempX)
    testY.append(tempY)

# %%
#generate training segments, ordered in score
look_forward=4
look_after=4
dataX,dataY=[],[]
dataXX,dataYY=[],[]
for idx_p,piece in enumerate(trainX):
    piece_notesX=[]
    piece_notesY=[]
    for idx_b,beat in enumerate(piece):
        tempX=[]
        tempfront=[]
        tempend=[]
        for i in reversed(range(1,look_forward+1)):
            if(idx_b-i)<0:
                tempfront.append(np.zeros(12))
            else:
                tempfront.append(np.array(piece[idx_b-i]))
        tempfront=np.array(tempfront)
        tempfront=np.sum(tempfront,axis=0)
          
        tempX.append(tempfront)
        tempX.append(piece[idx_b])

        for i in range(1,look_after+1):
            if(idx_b+i)>len(piece)-1:
                tempend.append(np.zeros(12))
            else:
                tempend.append(np.array(piece[idx_b+i]))

        tempend=np.sum(tempend,axis=0) 
        tempX.append(tempend)

        piece_notesX.append(tempX)
        piece_notesY.append(trainY[idx_p][idx_b])
    dataX.append(piece_notesX)
    dataY.append(piece_notesY)

for idx_p,piece in enumerate(testX):
    piece_notesX=[]
    piece_notesY=[]
    for idx_b,beat in enumerate(piece):
        tempX=[]
        tempfront=[]
        tempend=[]
        for i in reversed(range(1,look_forward+1)):
            if(idx_b-i)<0:
                tempfront.append(np.zeros(12))
            else:
                tempfront.append(np.array(piece[idx_b-i]))
        tempfront=np.array(tempfront)
        tempfront=np.sum(tempfront,axis=0)
          
        tempX.append(tempfront)
        tempX.append(piece[idx_b])

        for i in range(1,look_after+1):
            if(idx_b+i)>len(piece)-1:
                tempend.append(np.zeros(12))
            else:
                tempend.append(np.array(piece[idx_b+i]))

        tempend=np.sum(tempend,axis=0) 
        tempX.append(tempend)

        piece_notesX.append(tempX)
        piece_notesY.append(testY[idx_p][idx_b])
    dataXX.append(piece_notesX)
    dataYY.append(piece_notesY)

# %%
dataY[0][0].shape
# Out:
# (13, 1)

# %%
#turn the training/testing data(ordered in score) to tranable format(ordered in segments)
def trainable(X,Y):
  retX=[ b for x in X for b in x ]
  retX=np.array(retX)
  retY=[b for y in Y for b in y]
  retY=np.array(retY).reshape((-1,13))
  return retX,retY

# %%
processedX,processedY=trainable(dataX,dataY)
processedXX,processedYY=trainable(dataXX,dataYY)

# %%
processedX.shape,processedY.shape
# Out:
# ((8231, 3, 12), (8231, 13))

# %%
processedXX.shape,processedYY.shape
# Out:
# ((1576, 3, 12), (1576, 13))

# %%
#LSTM model (Key prediction)

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

# %%
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.layers import Bidirectional

# %%
#lstm model
def get_model():
  in_data = Input(shape=(3,12))

  lstm = LSTM(128,return_sequences=True)(in_data)#
  lstm = LSTM(12)(lstm)
  lstm = Flatten()(lstm)


  #lstm_2 = Dense(4,activation='relu')(lstm)
  #lstm_2 = Dense(2,activation='relu')(lstm_2)
  output2=Dense(1,activation='sigmoid',name='majorPrediction')(lstm)

  keyclassifier = Dense(64,activation='relu')(lstm)
  output=Dense(12,activation='softmax',name='keyPrediction')(lstm)


  

  model = Model(inputs=in_data, outputs=[output,output2])

  losses ={
          'keyPrediction':'categorical_crossentropy',
          'majorPrediction':'binary_crossentropy'    
        }

  lossWeights={
          'keyPrediction':0.7,
          'majorPrediction':0.3  
        }
      
  model.compile(  loss=losses,
                loss_weights= lossWeights,
                optimizer='adam',

                metrics=['accuracy'])
  return model

# %%
callback=EarlyStopping(
    monitor='val_loss', min_delta=0, patience=30, verbose=2, mode='auto',
    baseline=None, restore_best_weights=True)

# %%
#sample weights
classes={}
s=0
for e,m in zip(processedY[:,:-1],processedY[:,-1]):
  s+=1
  name=str(np.argmax(e))+' '+str(int(m))
  if name in classes:
    classes[name]+=1
  else:
    classes[name]=1

for e in classes:
  classes[e]=s / (24 * classes[e])

sample_weights=[]
for e,m in zip(processedY[:,:-1],processedY[:,-1]):
  name=str(np.argmax(e))+' '+str(int(m))
  sample_weights.append(classes[name])
sample_weights=np.array(sample_weights)
sample_weights.shape
# Out:
# (8231,)

# %%
#HMM model(chord prediction)
import sys
sys.path.append('../modules')
import HMM
h_states=[#Minor
      'MinorI', 'MinorI+',
      'MinorbII', 'MinorII',
      'MinorIII',
      'MinorIV', 'MinorIV+',
      'MinorV', 'MinorV+',
      'MinorVI', 'MinorGerVI', 'MinorFreVI', 'MinorItaVI',
      'MinorVII', 'MinorDimVII',
      #Major
      'MajorI',
      'MajorbII','MajorII',
      'MajorIII',
      'MajorIV',
      'MajorV',
      'MajorbVI','MajorGerVI','MajorFreVI','MajorItaVI','MajorVI',
      'MajorVII'
]

# %%
def prepareHMM(K_fold_selection):
  #  print(all_score[K_fold_selection[0]])
    pieces=[all_score[e] for e in K_fold_selection]
    HMM_data=[]
    current_chord=None
    current_key=None
    HMM_notes=[]
    HMM_chord=[]
    HMM_beats=[]
    for piece in pieces:
        data_chord=[]
        data_notes=[]
        data_beats=[]
        c = converter.parse(piece)
        all_notes=[]
        for el in c.recurse().notes:
            if el.lyric is not None:
                el.lyric=el.lyric.replace('♭','b')
            all_notes.append([el.lyric, el, cal_offset(el),el.duration.linked])
        
        
        #sort by first occurence
        b=sorted(all_notes,key=lambda x: (x[-2],x[0] if x[0] is not None else "ZZZZZZZZZZZZZZZ"))
        data_note={}
        for e in b:
   
            if current_chord is None and e[0] is None:
                continue
            elif e[0] is not None:
                if '(' in e[0]:
                    current_key=e[0].split('(')[0]
                    current_chord=e[0].split('(')[1].split(')')[0]
                else:
                    current_key=current_key
                    current_chord=e[0]
             
                major='M' if 'M' in current_key else 'm'
                
                chord=current_key[:-1]+major+'_'+current_chord
                data_chord.append(chord)
                data_beats.append(e[2])
                s=0
                for k,v in data_note.items():
                    s+=v
                for k,v in data_note.items():
                    data_note[k]=v/s
                data_notes.append(data_note)
                data_note={}

            for pitch in e[1].pitches:
                if pitch.name in data_note:
                    data_note[pitch.name]+=e[1].quarterLength*weight[int(pitch.nameWithOctave[-1])-1]
                    data_note[pitch.name]*=1.2 #reward for occurence
                else:
                    data_note[pitch.name]=e[1].quarterLength*weight[int(pitch.nameWithOctave[-1])-1]

        data_notes=data_notes[1:]
        data_notes.append(data_note)
        HMM_notes.append(data_notes)
        HMM_chord.append(data_chord)
        HMM_beats.append(data_beats)
        
        
    return HMM_notes,HMM_chord,HMM_beats

# %%
#tools for evaluation
from chordToNote import *
chords=['C','Db','D','Eb','E','F','F#','G','Ab','A','Bb','B']
M=['Minor','Major']

# %%
#10- fold crossvalidation
from sklearn.model_selection import KFold
import HMM
num_folds=20
kfold = KFold(n_splits=num_folds, shuffle=True)
fold_no = 1
acc_per_fold = []
loss_per_fold = []
acc2_per_fold=[]
acc3_per_fold=[]
k_fold_x=dataX+dataXX
k_fold_y=dataY+dataYY
k_fold_x=np.array(k_fold_x)
k_fold_y=np.array(k_fold_y)
HMM_score=0
HMM_count=0

for train, test in kfold.split(k_fold_x, k_fold_y):

  model=get_model()

  processedX,processedY=trainable(k_fold_x[train],k_fold_y[train])
  processedXX,processedYY=trainable(k_fold_x[test],k_fold_y[test])
  classes={}
  s=0
  for e,m in zip(processedY[:,:-1],processedY[:,-1]):
    s+=1
    name=str(np.argmax(e))+' '+str(int(m))
    if name in classes:
      classes[name]+=1
    else:
      classes[name]=1

  for e in classes:
    classes[e]=s / (24 * classes[e])

  sample_weights=[]
  for e,m in zip(processedY[:,:-1],processedY[:,-1]):
    name=str(np.argmax(e))+' '+str(int(m))
    sample_weights.append(classes[name])
  sample_weights=np.array(sample_weights)
  sample_weights.shape



  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  

  # Fit data to model
  history = model.fit(processedX, [processedY[:,:-1],processedY[:,-1]],
                      validation_data=(processedXX, [processedYY[:,:-1],processedYY[:,-1]]),
                      verbose=0, 
                      epochs=1000,
                      sample_weight=sample_weights,
                      callbacks=[callback],  
                      batch_size=1024,
                      shuffle=True)

  # Generate generalization metrics 
  # use different score explictly
  scores = model.evaluate(processedXX, [processedYY[:,:-1],processedYY[:,-1]], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[3]} of {scores[3]*100}%; {model.metrics_names[4]} of {scores[4]*100}%')

  # evaluate key prediction
  a,b=(model.predict(processedXX))
  key_count_all=0
  correct=0
  fifth=0
  parallel=0
  relative=0
  for idx,e in enumerate(processedYY):
      #exact match
      key_count_all+=1
      if np.argmax(processedYY[idx][:-1])==np.argmax(a[idx]) and processedYY[idx][-1]==(1 if b[idx]>=0.5 else 0):
          correct+=1
      else:
          if (np.argmax(processedYY[idx][:-1])+7)%12==np.argmax(a[idx]) and processedYY[idx][-1]==(1 if b[idx]>=0.5 else 0):
                fifth+=1
          elif np.argmax(processedYY[idx][:-1])==np.argmax(a[idx]) and processedYY[idx][-1]!=(1 if b[idx]>=0.5 else 0):
                parallel+=1
          elif processedYY[idx][-1]!=(1 if b[idx]>=0.5 else 0):
                if (1 if b[idx]>=0.5 else 0)==0:
                    if np.argmax(processedYY[idx][:-1])==((np.argmax(a[idx])+3)%12):
                        relative+=1
                elif np.argmax(processedYY[idx][:-1])==((np.argmax(a[idx])-3)%12):
                    relative+=1
  print('Correct:',correct,'Fifth:',fifth,'Relative:',relative,'parallel:',parallel,'Wrong:',key_count_all-correct-fifth-relative-parallel)
  print('Acc:',correct/(key_count_all),'weighted Acc:',(correct+0.5*fifth+0.3*relative+0.2*parallel)/key_count_all)

  #log acc of key_prediction
  acc_per_fold.append(((correct+0.5*fifth+0.3*relative+0.2*parallel)/key_count_all)* 100)
  acc2_per_fold.append(scores[3]* 100)
  acc3_per_fold.append(scores[4]* 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1
  
  #prepare HMM model
  n,c,_=prepareHMM(train)
  hmm_model=HMM.HMM(len(h_states),2,h_states,["outside chord","inside chord"])
  hmm_model.train_supervisied(n,c)#initialize parameter


  #prepare HMM test data
  testnotes,c,offsets=prepareHMM(test)
  key_name_scores=[]
  for test_id,test_piece in enumerate(offsets):
    o1,o2=model.predict(np.array(k_fold_x[test[test_id]]))
    key_name_score=[]
    #append len at end
    test_piece.append(len(o1))
    trace_id=0
    for i in range(len(test_piece)-1):
        temp=[]
        while trace_id<test_piece[i+1]:
            if (o2[trace_id][0]>=0.5)*1==0:
                name=chords[np.argmax(o1[trace_id])].lower()+M[(o2[trace_id][0]>=0.5)*1]
            else:
                name=chords[np.argmax(o1[trace_id])]+M[(o2[trace_id][0]>=0.5)*1]
            temp.append(name)
            trace_id+=1
        if len(temp)==0:
            key_name_score.append(key_name_score[-1])
        else:
            key_name_score.append(max(set(temp), key = temp.count))
    key_name_scores.append(key_name_score)

  #predict on HMM + evaluation
  for test_i in range(len(testnotes)):
      prediction=hmm_model.predict(testnotes[test_i],key_name_scores[test_i])
      prediction=[h_states[i] for i in prediction]
      predict_result=[]
      for pKey,p in zip(key_name_scores[test_i],prediction):
        if pKey=='gbMinor':
            pKey='f#Minor'
        elif pKey=='dbMinor':
            pKey='c#Minor'
        elif pKey=='abMinor':
            pKey='g#Minor'
        elif pKey=='d#Minor':
            pKey='ebMinor'
        #print(pKey, p[5:])
        p=p[5:]
        p=p.replace('7','')
        p=p.replace('Dim','DimVII')
        predict_result.append(ChordToNote(pKey, p))
      ground_result=[]
      for pKey in c[test_i]:
        m,p=pKey.split('_')
        m+='ajor' if 'M' in m else 'inor'
        if m=='Gbminor':
            m='F#minor'
        elif m=='Dbminor':
            m='C#minor'
        elif m=='Abminor':
            m='g#minor'
        elif m=='D#minor':
            m='ebminor'
        p=p.replace('7','')
        p=p.replace('Dim','DimVII')
        ground_result.append(ChordToNote(m, p))
      correct=0
      all=0
      for a,b in zip(predict_result,ground_result):
        all+=1
        if a[0]==b[0]:
            correct+=1
      print(all_score[test[test_i]],correct/all)
      HMM_score+=correct/all
      HMM_count+=1
# Out:
# <ipython-input-27-7e8328c2fbe2>:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   k_fold_x=np.array(k_fold_x)
# <ipython-input-27-7e8328c2fbe2>:14: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   k_fold_y=np.array(k_fold_y)
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00098: early stopping
# Score for fold 1: keyPrediction_accuracy of 76.34408473968506%; majorPrediction_accuracy of 83.97849202156067%
# Correct: 609 Fifth: 35 Relative: 30 parallel: 101 Wrong: 155
# Acc: 0.6548387096774193 weighted Acc: 0.7050537634408602
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_B_Minor_op104a.mxl 0.524390243902439
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Étude_in_F_Minor.mxl 0.6216216216216216
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(test)\Waltz_in_A_Minor.mxl 0.5502645502645502
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00192: early stopping
# Score for fold 2: keyPrediction_accuracy of 76.0831892490387%; majorPrediction_accuracy of 70.53726315498352%
# Correct: 336 Fifth: 18 Relative: 24 parallel: 103 Wrong: 96
# Acc: 0.5823223570190641 weighted Acc: 0.646100519930676
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Sonate_No._31.mxl 0.6428571428571429
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(test)\Piano_Sonata_No._11.mxl 0.6666666666666666
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# Score for fold 3: keyPrediction_accuracy of 60.15999913215637%; majorPrediction_accuracy of 80.47999739646912%
# Correct: 277 Fifth: 38 Relative: 4 parallel: 99 Wrong: 207
# Acc: 0.4432 weighted Acc: 0.5072
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Sonate_No._28_1stmovt.mxl 0.6691176470588235
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(test)\Il_Vecchio_Castello.mxl 0.48936170212765956
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# Score for fold 4: keyPrediction_accuracy of 67.08860993385315%; majorPrediction_accuracy of 67.51055121421814%
# Correct: 241 Fifth: 11 Relative: 23 parallel: 77 Wrong: 122
# Acc: 0.5084388185654009 weighted Acc: 0.5670886075949367
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Nocturne_in_F#_Major.mxl 0.3090909090909091
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Spring_Waltz.mxl 0.7959183673469388
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00114: early stopping
# Score for fold 5: keyPrediction_accuracy of 66.00000262260437%; majorPrediction_accuracy of 71.77777886390686%
# Correct: 237 Fifth: 23 Relative: 16 parallel: 60 Wrong: 114
# Acc: 0.5266666666666666 weighted Acc: 0.5895555555555556
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Nocturne_in_Eb_Major.mxl 0.47
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_F#_Major.mxl 0.3617021276595745
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00150: early stopping
# Score for fold 6: keyPrediction_accuracy of 70.42253613471985%; majorPrediction_accuracy of 70.95070481300354%
# Correct: 289 Fifth: 27 Relative: 0 parallel: 111 Wrong: 141
# Acc: 0.5088028169014085 weighted Acc: 0.5716549295774648
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Nocturne_in_E_Minor.mxl 0.6049382716049383
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(test)\Étude_in_C_Minor.mxl 0.6941176470588235
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00170: early stopping
# Score for fold 7: keyPrediction_accuracy of 74.27007555961609%; majorPrediction_accuracy of 82.84671306610107%
# Correct: 355 Fifth: 50 Relative: 27 parallel: 52 Wrong: 64
# Acc: 0.6478102189781022 weighted Acc: 0.7271897810218978
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Fugue_in_G_Minor.mxl 0.7305699481865285
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Moonlight_Sonata_1st_Movement.mxl 0.6666666666666666
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00109: early stopping
# Score for fold 8: keyPrediction_accuracy of 65.97164273262024%; majorPrediction_accuracy of 67.55629777908325%
# Correct: 594 Fifth: 127 Relative: 88 parallel: 197 Wrong: 193
# Acc: 0.4954128440366973 weighted Acc: 0.6032527105921601
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\G_minor.mxl 0.5189873417721519
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Waltz_in_Eb_Major.mxl 0.6043478260869565
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# Score for fold 9: keyPrediction_accuracy of 90.38461446762085%; majorPrediction_accuracy of 56.7307710647583%
# Correct: 54 Fifth: 0 Relative: 0 parallel: 40 Wrong: 10
# Acc: 0.5192307692307693 weighted Acc: 0.5961538461538461
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Musette_in_D.mxl 1.0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_A_Major.mxl 0.36363636363636365
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# Score for fold 10: keyPrediction_accuracy of 58.29307436943054%; majorPrediction_accuracy of 62.640899419784546%
# Correct: 235 Fifth: 94 Relative: 5 parallel: 127 Wrong: 160
# Acc: 0.3784219001610306 weighted Acc: 0.4974235104669887
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Nocturne_no._1.mxl 0.5454545454545454
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Waltz.mxl 0.75
# ------------------------------------------------------------------------
# Training for fold 11 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00085: early stopping
# Score for fold 11: keyPrediction_accuracy of 59.02965068817139%; majorPrediction_accuracy of 74.52830076217651%
# Correct: 323 Fifth: 133 Relative: 18 parallel: 115 Wrong: 153
# Acc: 0.4353099730458221 weighted Acc: 0.5632075471698113
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_Db_Major.mxl 0.7584269662921348
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Sonate_No._28.mxl 0.363013698630137
# ------------------------------------------------------------------------
# Training for fold 12 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00129: early stopping
# Score for fold 12: keyPrediction_accuracy of 79.0513813495636%; majorPrediction_accuracy of 86.56126260757446%
# Correct: 188 Fifth: 16 Relative: 14 parallel: 12 Wrong: 23
# Acc: 0.7430830039525692 weighted Acc: 0.800790513833992
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_B_Major.mxl 0.6956521739130435
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Étude_in_Gb_Major.mxl 0.6886792452830188
# ------------------------------------------------------------------------
# Training for fold 13 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# Score for fold 13: keyPrediction_accuracy of 67.00000166893005%; majorPrediction_accuracy of 78.33333611488342%
# Correct: 346 Fifth: 61 Relative: 14 parallel: 56 Wrong: 123
# Acc: 0.5766666666666667 weighted Acc: 0.6531666666666667
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Nocturne_in_B_Major.mxl 0.5878787878787879
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Étude_in_F_Major.mxl 0.6744186046511628
# ------------------------------------------------------------------------
# Training for fold 14 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00280: early stopping
# Score for fold 14: keyPrediction_accuracy of 86.14457845687866%; majorPrediction_accuracy of 91.86747074127197%
# Correct: 273 Fifth: 7 Relative: 3 parallel: 13 Wrong: 36
# Acc: 0.822289156626506 weighted Acc: 0.8433734939759037
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_B_Minor.mxl 0.7297297297297297
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Sonatina_in_G.mxl 0.8617021276595744
# ------------------------------------------------------------------------
# Training for fold 15 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00201: early stopping
# Score for fold 15: keyPrediction_accuracy of 70.57291865348816%; majorPrediction_accuracy of 86.45833134651184%
# Correct: 250 Fifth: 12 Relative: 4 parallel: 21 Wrong: 97
# Acc: 0.6510416666666666 weighted Acc: 0.6807291666666666
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Nocturne_No._20_in_C#_Minor.mxl 0.5934065934065934
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Solfeggietto_in_C_minor.mxl 0.7551020408163265
# ------------------------------------------------------------------------
# Training for fold 16 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# Score for fold 16: keyPrediction_accuracy of 72.35772609710693%; majorPrediction_accuracy of 63.41463327407837%
# Correct: 200 Fifth: 8 Relative: 19 parallel: 67 Wrong: 75
# Acc: 0.5420054200542005 weighted Acc: 0.6046070460704607
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Minuet_in_G_Major.mxl 0.9333333333333333
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\sonata_no_1.mxl 0.525
# ------------------------------------------------------------------------
# Training for fold 17 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# Score for fold 17: keyPrediction_accuracy of 74.61928725242615%; majorPrediction_accuracy of 69.03553009033203%
# Correct: 105 Fifth: 8 Relative: 4 parallel: 42 Wrong: 38
# Acc: 0.5329949238578681 weighted Acc: 0.6020304568527919
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Menuet_in_G_Minor.mxl 0.6
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_E_Minor.mxl 0.3404255319148936
# ------------------------------------------------------------------------
# Training for fold 18 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00121: early stopping
# Score for fold 18: keyPrediction_accuracy of 75.0%; majorPrediction_accuracy of 77.4193525314331%
# Correct: 78 Fifth: 4 Relative: 5 parallel: 15 Wrong: 22
# Acc: 0.6290322580645161 weighted Acc: 0.6814516129032258
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Minuet_in_F.mxl 0.76
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(test)\Prélude_in_C_Minor.mxl 0.7708333333333334
# ------------------------------------------------------------------------
# Training for fold 19 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00159: early stopping
# Score for fold 19: keyPrediction_accuracy of 83.05084705352783%; majorPrediction_accuracy of 96.18644118309021%
# Correct: 193 Fifth: 13 Relative: 0 parallel: 3 Wrong: 27
# Acc: 0.8177966101694916 weighted Acc: 0.8478813559322034
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Prélude_in_G_Major.mxl 0.45454545454545453
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Twinkle-Twinkle.mxl 0.9090909090909091
# ------------------------------------------------------------------------
# Training for fold 20 ...
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# Score for fold 20: keyPrediction_accuracy of 50.0%; majorPrediction_accuracy of 63.92405033111572%
# Correct: 172 Fifth: 17 Relative: 14 parallel: 65 Wrong: 206
# Acc: 0.3628691983122363 weighted Acc: 0.4170886075949367
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Nocturne_in_C#_Minor.mxl 0.49572649572649574
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ../musicxml(train)\Étude_in_Gb_Major_Op25.mxl 0.5277777777777778

# %%
#acc: key+chord prediction
HMM_score/HMM_count
# Out:
# 0.6244988388547805

# %%
# == key prediction ACC==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Key&Maj weighted Accuracy: {acc_per_fold[i]}% - Key Accuracy: {acc2_per_fold[i]}% - Maj Accuracy: {acc3_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Total weighted Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> KeyAccuracy: {np.mean(acc2_per_fold)} (+- {np.std(acc2_per_fold)})')
print(f'> MajAccuracy: {np.mean(acc3_per_fold)} (+- {np.std(acc3_per_fold)})')
print(f'> Total Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.7642790675163269 - Key&Maj Accuracy: 70.50537634408602% - Key Accuracy: 76.34408473968506% - Maj Accuracy: 83.97849202156067%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6683140993118286 - Key&Maj Accuracy: 64.6100519930676% - Key Accuracy: 76.0831892490387% - Maj Accuracy: 70.53726315498352%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.8247166275978088 - Key&Maj Accuracy: 50.72% - Key Accuracy: 60.15999913215637% - Maj Accuracy: 80.47999739646912%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.7428193092346191 - Key&Maj Accuracy: 56.708860759493675% - Key Accuracy: 67.08860993385315% - Maj Accuracy: 67.51055121421814%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.8311247825622559 - Key&Maj Accuracy: 58.95555555555556% - Key Accuracy: 66.00000262260437% - Maj Accuracy: 71.77777886390686%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.8629409670829773 - Key&Maj Accuracy: 57.16549295774648% - Key Accuracy: 70.42253613471985% - Maj Accuracy: 70.95070481300354%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.696540892124176 - Key&Maj Accuracy: 72.71897810218978% - Key Accuracy: 74.27007555961609% - Maj Accuracy: 82.84671306610107%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 1.038732886314392 - Key&Maj Accuracy: 60.325271059216014% - Key Accuracy: 65.97164273262024% - Maj Accuracy: 67.55629777908325%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.5493120551109314 - Key&Maj Accuracy: 59.61538461538461% - Key Accuracy: 90.38461446762085% - Maj Accuracy: 56.7307710647583%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 1.0702461004257202 - Key&Maj Accuracy: 49.74235104669887% - Key Accuracy: 58.29307436943054% - Maj Accuracy: 62.640899419784546%
# ------------------------------------------------------------------------
# > Fold 11 - Loss: 0.9810703992843628 - Key&Maj Accuracy: 56.32075471698113% - Key Accuracy: 59.02965068817139% - Maj Accuracy: 74.52830076217651%
# ------------------------------------------------------------------------
# > Fold 12 - Loss: 0.6298021674156189 - Key&Maj Accuracy: 80.0790513833992% - Key Accuracy: 79.0513813495636% - Maj Accuracy: 86.56126260757446%
# ------------------------------------------------------------------------
# > Fold 13 - Loss: 0.8949607610702515 - Key&Maj Accuracy: 65.31666666666666% - Key Accuracy: 67.00000166893005% - Maj Accuracy: 78.33333611488342%
# ------------------------------------------------------------------------
# > Fold 14 - Loss: 0.4401271343231201 - Key&Maj Accuracy: 84.33734939759037% - Key Accuracy: 86.14457845687866% - Maj Accuracy: 91.86747074127197%
# ------------------------------------------------------------------------
# > Fold 15 - Loss: 0.7678442001342773 - Key&Maj Accuracy: 68.07291666666666% - Key Accuracy: 70.57291865348816% - Maj Accuracy: 86.45833134651184%
# ------------------------------------------------------------------------
# > Fold 16 - Loss: 1.0464469194412231 - Key&Maj Accuracy: 60.46070460704607% - Key Accuracy: 72.35772609710693% - Maj Accuracy: 63.41463327407837%
# ------------------------------------------------------------------------
# > Fold 17 - Loss: 0.7742339968681335 - Key&Maj Accuracy: 60.203045685279186% - Key Accuracy: 74.61928725242615% - Maj Accuracy: 69.03553009033203%
# ------------------------------------------------------------------------
# > Fold 18 - Loss: 0.6465262770652771 - Key&Maj Accuracy: 68.14516129032258% - Key Accuracy: 75.0% - Maj Accuracy: 77.4193525314331%
# ------------------------------------------------------------------------
# > Fold 19 - Loss: 0.41971248388290405 - Key&Maj Accuracy: 84.78813559322033% - Key Accuracy: 83.05084705352783% - Maj Accuracy: 96.18644118309021%
# ------------------------------------------------------------------------
# > Fold 20 - Loss: 1.1640136241912842 - Key&Maj Accuracy: 41.708860759493675% - Key Accuracy: 50.0% - Maj Accuracy: 63.92405033111572%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Total Accuracy: 63.524998460005236 (+- 10.896075532925314)
# > KeyAccuracy: 71.0922110080719 (+- 9.634296174958223)
# > MajAccuracy: 75.13690888881683 (+- 10.306648499176479)
# > Total Loss: 0.7906882375478744
# ------------------------------------------------------------------------
