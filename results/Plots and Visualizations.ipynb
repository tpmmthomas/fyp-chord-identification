# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
loss1 = np.load('loss.npy')#LSTM version
loss2 = np.load('loss2.npy') #DQN non-normalized

# %%
df = pd.read_csv("loss_dqn_normalized.csv")
loss2 = df['loss'].values
df = pd.read_csv("loss2.csv")
loss1 = df['loss'].values

# %%
plt.plot(loss1)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss of LSTM-DQN (non-normalized)")
# Out:
# Text(0.5, 1.0, 'Loss of LSTM-DQN (non-normalized)')

# %%
plt.plot(loss2)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss of DQN (normalized)")
# Out:
# Text(0.5, 1.0, 'Loss of DQN (normalized)')
